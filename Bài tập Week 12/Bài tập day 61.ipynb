# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

filename = librosa.example("nutcracker")
#Load the audio as a waveform ‘y‘
# Store the sampling rate as ‘sr ‘
audio , sr = librosa . load ( filename )


time = np.linspace(0, audio . shape [0] / sr , num= audio . shape [0])
plt.plot (time, audio, color ="blue")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude ( quantized )")
plt.title("Wav file visualization ")
plt.axhline(y=0, color ="r", linestyle = "-")
plt.show()

# %%
import speech_recognition as sr

# Khởi tạo Recognizer
r = sr.Recognizer()
audio_filename = "/home/dangnhatminh92/Documents/AIO/AIO_2025/WARMING UP/Coding/Bài tập Week 12/data.wav"

# Đọc file âm thanh
with sr.AudioFile(audio_filename) as source:
    audio = r.record(source)  # Ghi lại toàn bộ audio

# In ra kiểu dữ liệu
print(type(audio))

# Chuyển giọng nói sang văn bản (tiếng Việt)
try:
    your_speech = r.recognize_google(audio, language="vi-VN")
    print("Audio transcription:", your_speech)
except sr.UnknownValueError:
    print("Google Speech Recognition không nhận diện được nội dung.")
except sr.RequestError as e:
    print(f"Lỗi khi gọi Google API: {e}")
# Out:
# <class 'speech_recognition.audio.AudioData'>
# Audio transcription: hiện ra tận phía xa

# %%
from gtts import gTTS
import librosa
import numpy as np

lang ="vi"
output_filename = "record.mp3"
content = "xin chào mọi người"
output = gTTS(content, lang =lang, slow = False) # text to speech

output.save(output_filename) # save google audio to a file
data , sr = librosa.load(output_filename) # load google audio using librosa library

import IPython
IPython.display.display(IPython.display.Audio(np.transpose(data),rate =sr)) # display audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

filename = librosa.example("brahms")
#Load the audio as a waveform ‘y‘
# Store the sampling rate as ‘sr ‘
audio , sr = librosa .load(filename)


time = np.linspace(0, audio .shape[0] / sr , num= audio.shape[0])
plt.plot (time, audio, color ="blue")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude ( quantized )")
plt.title("Wav file visualization ")
plt.axhline(y=0, color ="r", linestyle = "-")
plt.show()
# Out:
# Downloading file 'Hungarian_Dance_number_5_-_Allegro_in_F_sharp_minor_(string_orchestra).ogg' from 'https://librosa.org/data/audio/Hungarian_Dance_number_5_-_Allegro_in_F_sharp_minor_(string_orchestra).ogg' to '/home/dangnhatminh92/.cache/librosa'.

# %%
test_case_2 = "Tôi yêu AIO"
from gtts import gTTS
import librosa
import numpy as np

lang ="vi"
output_filename = "record2.mp3"
test_case_2 = "Tôi yêu AIO"
output = gTTS(test_case_2, lang =lang, slow = False) # text to speech

output.save(output_filename) # save google audio to a file
data , sr = librosa.load(output_filename) # load google audio using librosa library

import IPython
IPython.display.display(IPython.display.Audio(np.transpose(data),rate =sr)) # display audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import speech_recognition as sr

# Khởi tạo Recognizer
r = sr.Recognizer()
test_case_2 = "/home/dangnhatminh92/Documents/AIO/AIO_2025/WARMING UP/Coding/Bài tập Week 12/data02.wav"

# Đọc file âm thanh
with sr.AudioFile(test_case_2) as source:
    audio = r.record(source)  # Ghi lại toàn bộ audio

# In ra kiểu dữ liệu
print(type(audio))

# Chuyển giọng nói sang văn bản (tiếng Việt)
try:
    your_speech = r.recognize_google(audio, language="vi-VN")
    print("Audio transcription:", your_speech)
except sr.UnknownValueError:
    print("Google Speech Recognition không nhận diện được nội dung.")
except sr.RequestError as e:
    print(f"Lỗi khi gọi Google API: {e}")
# Out:
# <class 'speech_recognition.audio.AudioData'>
# Audio transcription: Xin chào kế Linh
